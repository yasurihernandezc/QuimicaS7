# %% [markdown]
# <a href="https://colab.research.google.com/github/yasurihernandezc/QuimicaS7/blob/main/Gases_parte2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gases (continuación)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Ejemplo 1: Graficar en barras el número de participaciones de los países en el mundial, según Wikipedia

# %%
url = 'https://es.wikipedia.org/wiki/Anexo:Estad%C3%ADsticas_de_la_Copa_Mundial_de_F%C3%BAtbol'
tablas = pd.read_html(url)

# %%
tablas[9].head(10)
# Out:
#     #   Selección  Apariciones  \
# 0  1°      Brasil           20
# 1  2°    Alemania           18
# 2  3°   Argentina           17
# 3  3°      México           17
# 4  4°      Italia           16
# 5  4°  Inglaterra           16
# 6  5°      España           15
# 7  6°     Francia           14
# 8  6°     Uruguay           14
# 9  7°      Serbia           13
#
#                                              Mundial Rendimiento
# 0  1930, 1950, 1954, 1958, 1962, 1966, 1970, 1974...      90,00%
# 1  1954, 1958, 1962, 1966, 1970, 1974, 1978, 1982...      88,89%
# 2  1930, 1958, 1962, 1966, 1974, 1978, 1982, 1986...      82,35%
# 3  1930, 1950, 1954, 1958, 1962, 1966, 1970, 1978...      52,94%
# 4  1950, 1954, 1962, 1966, 1970, 1974, 1978, 1982...      56,25%
# 5  1950, 1954, 1958, 1962, 1966, 1970, 1982, 1986...      81,25%
# 6  1950, 1962, 1966, 1978, 1982, 1986, 1990, 1994...      66,66%
# 7  1930, 1954, 1958, 1966, 1978, 1982, 1986, 1998...      57,14%
# 8  1930, 1950, 1954, 1962, 1966, 1970, 1974, 1986...      71,43%
# 9  1930, 1950, 1954, 1958, 1962, 1974, 1982, 1990...      53,84%

# %%
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
plt.bar(tablas[9]['Selección'],tablas[9]['Apariciones'])
# Out:
# <BarContainer object of 78 artists>

# %% [markdown]
# Ejemplo 2: Hacer una gráfica de barras de las canciones más reproducidas en Spotify

# %%
pagina = 'https://es.wikipedia.org/wiki/Anexo:Canciones_m%C3%A1s_reproducidas_en_Spotify'
tablas = pd.read_html(pagina)

# %%
tablas[13]
# Out:
#                             Álbum            Artista  \
# 0         Midnights (3am Edition)       Taylor Swift
# 1             Certified Lover Boy              Drake
# 2                Un verano sin ti          Bad Bunny
# 3                        Scorpion              Drake
# 4    Speak Now (Taylor's Version)       Taylor Swift
# 5                For All The Dogs              Drake
# 6   Mr. Morale & the Big Steppers     Kendrick Lamar
# 7                   Harry's House       Harry Styles
# 8                        Her Loss  Drake y 21 Savage
# 9                           Donda         Kayne West
# 10         Red (Taylor's Version)       Taylor Swift
# 11                       Folklore       Taylor Swift
# 12           Beerbongs & Bentleys        Post Malone
# 13       EL ÚLTIMO TOUR DEL MUNDO          Bad Bunny
# 14                             Al                 Al
#
#    Reproducciones (en millones)     Fecha de lanzamiento    Ref.
# 0                         184.7    21 de octubre de 2022     NaN
# 1                         154.9  3 de septiembre de 2021  [108]​
# 2                         146.4        6 de mayo de 2022     NaN
# 3                         132.4      29 de junio de 2018  [109]​
# 4                         124.0       7 de julio de 2023     NaN
# 5                         109.0     6 de octubre de 2023     NaN
# 6                          99.9       13 de mayo de 2022     NaN
# 7                          97.6       20 de mayo de 2022     NaN
# 8                          97.3   4 de noviembre de 2022     NaN
# 9                          94.4     29 de agosto de 2021     NaN
# 10                         90.5  12 de noviembre de 2021     NaN
# 11                         79.4      24 de julio de 2020     NaN
# 12                         78.7      27 de abril de 2018  [110]​
# 13                         74.9  27 de noviembre de 2020     NaN
# 14                           Al                       Al      Al

# %%
plt.xticks(rotation=60)
plt.bar(tablas[13]['Artista'],tablas[13]['Reproducciones (en millones)'])
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# Ejemplo 3: Hacer un diagrama de barras del Potencial de calentamiento global (PCA) para un tiempo de 20 años para los gases:
#
# Dióxido de carbono
#
# Metano
#
# Óxido nitroso
#
# Diclorodifluorometano
#
# Clorodifluorometano
#
# Tetrafluorometano
#
# Hexafluoretano
#
# Hexafluoruro de azufre
#
# Trifluoruro de nitrógeno

# %%
url = "https://es.wikipedia.org/wiki/Gas_de_efecto_invernadero"
tabla = pd.read_html(url)

# %%
tabla[0]
# Out:
#                                            Compuesto  \
# 0                              Vapor de agua y nubes
# 1                                 Dióxido de carbono
# 2                                             Metano
# 3                                              Ozono
# 4  (A) El vapor de agua varía mucho localmente (B...
#
#                                              Fórmula  \
# 0                                               H 2O
# 1                                                CO2
# 2                                               CH 4
# 3                                                O 3
# 4  (A) El vapor de agua varía mucho localmente (B...
#
#                  Concentración en la atmósfera (ppm)  \
# 0                                       10–50 000(A)
# 1                                               ~400
# 2                                               ~1.8
# 3                                             2–8(B)
# 4  (A) El vapor de agua varía mucho localmente (B...
#
#                                     Contribución (%)
# 0                                             36–72%
# 1                                              9–26%
# 2                                               4–9%
# 3                                               3–7%
# 4  (A) El vapor de agua varía mucho localmente (B...

# %%
tabla[1]
# Out:
#              Nombre del gas Fórmula química Años de vida  \
#              Nombre del gas Fórmula química Años de vida
# 0        Dióxido de carbono             CO2        30–95
# 1                    Metano             CH4           12
# 2             Óxido nitroso             N2O          121
# 3     Diclorodifluorometano          CCl2F2          100
# 4       Clorodifluorometano          CHClF2           12
# 5         Tetrafluorometano             CF4       50 000
# 6            Hexafluoretano            C2F6       10 000
# 7    Hexafluoruro de azufre             SF6        3 200
# 8  Trifluoruro de nitrógeno             NF3          500
#
#   Potencial de calentamiento global (PCA) para un tiempo determinado           \
#                                                              20 años 100 años
# 0                                                  1                        1
# 1                                                 84                       28
# 2                                                264                      265
# 3                                             10 800                   10 200
# 4                                              5 280                    1 760
# 5                                              4 880                    6 630
# 6                                              8 210                   11 100
# 7                                             17 500                   23 500
# 8                                             12 800                   16 100
#
#
#   500 años
# 0        1
# 1      7.6
# 2      153
# 3    5 200
# 4      549
# 5   11 200
# 6   18 200
# 7   32 600
# 8   20 700

# %%
tabla[1]["Nombre del gas"]
# Out:
#              Nombre del gas
# 0        Dióxido de carbono
# 1                    Metano
# 2             Óxido nitroso
# 3     Diclorodifluorometano
# 4       Clorodifluorometano
# 5         Tetrafluorometano
# 6            Hexafluoretano
# 7    Hexafluoruro de azufre
# 8  Trifluoruro de nitrógeno

# %%
tabla[1]["Fórmula química"]
# Out:
#   Fórmula química
# 0             CO2
# 1             CH4
# 2             N2O
# 3          CCl2F2
# 4          CHClF2
# 5             CF4
# 6            C2F6
# 7             SF6
# 8             NF3

# %%
tabla[1]["Potencial de calentamiento global (PCA) para un tiempo determinado"]
# Out:
#   20 años 100 años 500 años
# 0       1        1        1
# 1      84       28      7.6
# 2     264      265      153
# 3  10 800   10 200    5 200
# 4   5 280    1 760      549
# 5   4 880    6 630   11 200
# 6   8 210   11 100   18 200
# 7  17 500   23 500   32 600
# 8  12 800   16 100   20 700

# %%
tabla[1]["Potencial de calentamiento global (PCA) para un tiempo determinado"]["20 años"]
# Out:
# 0         1
# 1        84
# 2       264
# 3    10 800
# 4     5 280
# 5     4 880
# 6     8 210
# 7    17 500
# 8    12 800
# Name: 20 años, dtype: object

# %%
y = pd.DataFrame([[1,84,264,10800,5280,4880,8210,17500,12800]])
y = y.transpose()
y

# %%
FormulaQuimica = ["CO2","CH4","N2O","CCl2F2","CHClF2","CF4","C2F6","SF6","NF3"]
PCA = [1,84,264,10800,5280,4880,8210,17500,12800]

plt.bar(FormulaQuimica,PCA)
plt.show()

# %% [markdown]
# Ejemplo 4: Representar la composición química usando un diagrama circular para:
#
# compuestos = ['carbono','hidrogeno','oxigeno','nitrogeno']
#
# numero = [3,14,2,1]

# %%
compuestos = ['carbono','hidrogeno','oxigeno','nitrogeno']
numero = [3,14,2,1]

plt.pie(numero, labels = compuestos);

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')


# make data
x = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D, positions=[2, 4, 6], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (0.75, 1.00, 0.75), (200, 3))

# plot:
fig, ax = plt.subplots()

vp = ax.violinplot(D, [2, 4, 6], widths=2,
                   showmeans=False, showmedians=False, showextrema=False)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.9)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# Ejemplo 4:

# %%
# instalamos:
# %%capture
# !pip install drawdata

# %%
# Importamos
from drawdata import draw_scatter, draw_histogram, draw_line

# seleccionar A y graficar  la distribución
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("data.csv")
df
# Out:
#               x           y  z
# 0     90.590322   99.732296  a
# 1     60.574828  101.363326  a
# 2     88.862071  138.395662  a
# 3     99.699413  126.920476  a
# 4     89.638117  111.537193  a
# ..          ...         ... ..
# 669   63.809234   80.705275  c
# 670   67.044653   85.939815  c
# 671   82.878206   31.545537  c
# 672   68.132827   72.046974  c
# 673  107.661285   28.833920  c
#
# [674 rows x 3 columns]

# %% [markdown]
# medidas de tendencia central

# %%
df["x"].mean()
# Out:
# 331.7682990596369

# %%
df["x"].median()
# Out:
# 328.3727209579007

# %% [markdown]
# medidas de dispersion

# %%
df['x'].quantile([.25, .5, .75])
# Out:
# 0.25    180.436698
# 0.50    328.372721
# 0.75    474.595524
# Name: x, dtype: float64

# %%
df['x'].max() - df['x'].min()
# Out:
# 646.3759164947342

# %%
# desviación estándar
round(df['x'].std(),2)
# Out:
# 170.68

# %%
round(df.describe(),2)
# Out:
#             x       y
# count  674.00  674.00
# mean   331.77  214.30
# std    170.68  112.73
# min     30.76    8.43
# 25%    180.44  121.81
# 50%    328.37  201.62
# 75%    474.60  296.10
# max    677.13  492.76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       674 non-null    float64
#  1   y       674 non-null    float64
#  2   z       674 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 15.9+ KB

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo con 10 filas
data = {'Categoría': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
        'Valor': [12, 18, 5, 22, 15, 10, 30, 8, 17, 14]}
df = pd.DataFrame(data)

# Crear un gráfico de barras utilizando Seaborn
plt.figure(figsize=(8, 6))  # Ajusta el tamaño de la figura si es necesario
sns.barplot(x='Categoría', y='Valor', data=df)

# Agregar etiquetas y título
plt.xlabel('Categoría--')
plt.ylabel('Valor')
plt.title('Diagrama de Barras')

# Mostrar el gráfico
plt.show()

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df2 = pd.read_csv("data_2.csv")
df2

# %% [markdown]
# Actividad: Elaborar dataframes y comparar sus medidas de tendencia central para explicar las gráficas (Ref. Teoría cinética molecular de los gases)

# %% [markdown]
# ![boltz_maxw.PNG](data:image/png;base64,...)

# %% [markdown]
# grafico 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# instalamos:
# %%capture
# !pip install drawdata

# %%
# Importamos
from drawdata import draw_scatter, draw_histogram, draw_line

# seleccionar A y graficar  la distribución
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("data_4.csv")
df
# Out:
#          x         y  z
# 0    0.000  0.164667  a
# 1    0.025  0.176667  a
# 2    0.050  0.316667  a
# 3    0.075  0.796667  a
# 4    0.100  0.964667  a
# ..     ...       ... ..
# 115  0.875  0.032667  c
# 116  0.900  0.028667  c
# 117  0.925  0.024667  c
# 118  0.950  0.022667  c
# 119  0.975  0.022667  c
#
# [120 rows x 3 columns]

# %%
df["x"].mean()
# Out:
# 0.4875

# %%
df["x"].median()
# Out:
# 0.4875

# %% [markdown]
# grafico 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importamos
from drawdata import draw_scatter, draw_histogram, draw_line

# seleccionar A y graficar  la distribución
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("data_5.csv")
df
# Out:
#          x         y  z
# 0    0.000  0.056667  a
# 1    0.025  0.216667  a
# 2    0.050  0.350667  a
# 3    0.075  0.988667  a
# 4    0.100  0.898667  a
# ..     ...       ... ..
# 115  0.875  0.048667  c
# 116  0.900  0.044667  c
# 117  0.925  0.036667  c
# 118  0.950  0.034667  c
# 119  0.975  0.034667  c
#
# [120 rows x 3 columns]

# %%
df["x"].mean()
# Out:
# 0.4875

# %%
df["x"].median()
# Out:
# 0.4875
