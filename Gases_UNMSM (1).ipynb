# %% [markdown]
# # Gases Ideales
#
# Jesus Alvarado

# %% [markdown]
# # Pregunta 1.

# %%
# 1. El huracán Sandy (“supertormenta Sandy”) fue uno de los más destructivos en
# los últimos años y afectó el Caribe, Cuba, las Bahamas y 24 estados de la
# costa este de Estados Unidos. La presión más baja registrada en este huracán
# fue de 705 mmHg. ¿Cuál fue la presión en kPa?
# Dato: 1 atm = 1.01325x10E5 Pa = 760 mmHg

presion_mmHg = 705 # mmHg
presion_kPa = presion_mmHg*((1.01325*100)/760)
print("la presion en kPa es:", round(presion_kPa,2))
# Out:
# la presion en kPa es: 93.99

# %% [markdown]
# # Pregunta 2.

# %%
# Ordene de menor a mayor las siguientes presiones:
# a) 736 mmHg, b) 0.928 atm, c) 728 torr, d) 1.12 x10E5 Pa.

1#mmHg = 1 #torr
a= 736 #mmHg
print("a es", round(a,2))

1#atm = 760 #torr
b= 0.928*760
print("b es", round(b,2))
c= 728 #torr
print("c es", c)

1 #Pa = 0.0075006 #torr
d= ((1.12*100000*760)/101325)
print("d es", round(d,2))

print("el orden de menor a mayor es b,c,a,d, respectivamente: ",b,c,a,d)
# Out:
# a es 736
# b es 705.28
# c es 728
# d es 840.07
# el orden de menor a mayor es b,c,a,d, respectivamente:  705.2800000000001 728 736 840.0690846286702

# %% [markdown]
# ¿En dónde sería más fácil beber agua con un popote, en la cima o al pie del monte
# Everest?

# %% [markdown]
# # Pregunta 3.

# %%
# Compare los cambios de volumen cuando se duplica la temperatura de un gas a
# presión constante de a) 200 K a 400 K y b) 200 ºC a 400 ºC.
# ¿Cuando hay mayor variación en el volumen?

T1= 200
T2= 400
T3= 200+273.15
T4= 400+273.15

a= (T2/T1)
b= (T4/T3)
print("la variacion del volumen final de a es", round(a,2))
print("la variacion del volumen final de b es", round(b,2))
resultado = a
print("hay mayor variacion en el volumen de", round(resultado,2))
# Out:
# la variacion del volumen final de a es 2.0
# la variacion del volumen final de b es 1.42
# hay mayor variacion en el volumen de 2.0

# %% [markdown]
# # Pregunta 4.

# %% [markdown]
# ![pelota_22_4L.PNG](data:image/png;base64,...)

# %%
# Relación entre volumen y cantidad:
# El hexafl uoruro de azufre (SF6) es un gas incoloro e inodoro muy poco reactivo.
# Calcule la presión (en atm) ejercida por 1.82 moles del gas en un recipiente
# de acero de 5.43 L de volumen a 69.5 ºC.
# Dato: R = 0.082057 L atm / K mol

n_moles = 1.82
volumen = 5.43
temperatura =(69.5+273.15)

resultado=((n_moles*0.082057*(342.65))/volumen)
print("la presion ejercida en el recipiente de acero es", round(resultado,2))
# Out:
# la presion ejercida en el recipiente de acero es 9.42

# %% [markdown]
# # Pregunta 5.

# %%
# Calcule el volumen (en litros) ocupado por 2.12 moles de óxido nítrico (NO) a
# 6.54 atm y 76 ºC.

n_moles= 2.12
r= 0.082057
p= 6.54
t= 76+273.15

v= ((n_moles*r*t)/p)
print("el volumen es de",round(v,2))
# Out:
# el volumen es de 9.29

# %% [markdown]
# # Pregunta 6.

# %%
# El amoniaco gaseoso se emplea como refrigerante en el procesamiento de
# alimentos y la industria del almacenamiento. Calcule el volumen (en litros)
# ocupado por 7.40 g de NH3 a TPE.
# Dato: 1 mol de un gas ideal ocupa 22.41 L a TPE

# %% [markdown]
# # Pregunta 7.

# %%
# Suponiendo un comportamiento ideal, ¿cuál de los siguientes gases tendrá el
# mayor volumen a TPE? a) 0.82 moles de He. b) 24 g de N2. c) 5.0 3 10E3
# moléculas de Cl2. ¿Cuál gas tiene la mayor densidad?

# %% [markdown]
# # Pregunta 8.

# %%
# Un globo infl ado con un volumen de 0.55 L de helio a nivel del mar (1.0 atm)
# se deja elevar a una altura de 6.5 km, donde la presión es de casi 0.40 atm.
# Suponiendo que la temperatura permanece constante, ¿cuál será el volumen final
# del globo?


P_1= 1.0 #atm
V_1= 0.55 #L
P_2= 0.40 #atm

V_2 = ((P_1*V_1)/(P_2))

print("el volumen final del globo es:",V_2)
# Out:
# el volumen final del globo es: 1.375

# %% [markdown]
# # Pregunta 9.

# %%
# Una muestra de cloro gaseoso ocupa un volumen de 946 mL a una presión de
# 726 mmHg. Calcule la presión del gas (en mmHg) si el volumen se reduce a
# temperatura constante a 154 mL.


p_1= 726 #mmHg
v_1= 946 #mL
v_2= 154 #mL

p_2= ((p_1*v_1)/(v_2))
print("la presion del gas será de:",p_2)
# Out:
# la presion del gas será de: 4459.714285714285

# %% [markdown]
# # Pregunta 10.

# %%
# El argón es un gas inerte que se emplea en los focos para retrasar la
# vaporización del fi lamento del tungsteno. Cierto foco que contiene argón a
# 1.20 atm y 18 ºC se calienta a 858C a volumen constante. Calcule su presión
# final (en atm).


p_1= 1.20 #atm
t_1= 291.15 #K
t_2= 1131.15 #K

p_2= ((p_1*t_2)/(t_1))
print(" la presion final es de",p_2)
# Out:
#  la presion final es de 4.662132921174653

# %% [markdown]
# # Pregunta 11.

# %%
# Una pequeña burbuja se eleva desde el fondo de un lago, donde la temperatura
# y presión son de 8 ºC y 6.4 atm, hasta la superfi cie del agua, donde la
# temperatura es de 25 ºC y la presión de 1.0 atm. Calcule el volumen final de
# la burbuja (en mL) si su volumen inicial era de 2.1 mL.


p_1= 6.4 #atm
v_1= 2.1 #mL
t_1= 281.15 #K
p_2= 1.0 #atm
t_2= 298.15 #K

V_2= ((p_1*v_1*t_2)/(p_2*t_1))
print("el volumen final de la burbuja es:",round(V_2,2))
# Out:
# el volumen final de la burbuja es: 14.25

# %% [markdown]
# # Pregunta 12.

# %%
# Un gas que inicialmente tiene un volumen de 4.0 L a 1.2 atm y 66 ºC
# experimenta un cambio de manera que su volumen y temperatura finales se
# convierten en 1.7 L y 42 ºC. ¿Cuál es su presión final? Suponga que el número
# de moles no ha cambiado.


p_1= 1.2 #atm
v_1= 4.0 #L
t_1= 339.15 #K
v_2= 1.7 #L
t_2= 315.15 #K

p_2= ((p_1*v_1*t_2)/(t_1*v_2))

print("su presion final es",round(p_2,2))
# Out:
# su presion final es 2.62

# %% [markdown]
# # Pregunta 13.

# %%
# Calcule la densidad del dióxido de carbono (CO2) en gramos por litro (g/L) a
# 0.990 atm y 55 ºC.



P= 0.990
V= 1 #L
R= 0.0821
T= 328.15
masa_molar= 44.01

D= ((P*masa_molar)/(R*T))
print("la densidad es",round(D,2))

# %% [markdown]
# # Pregunta 14.

# %%
# ¿Cuál es la densidad (en g/L) del hexafl uoruro de uranio (UF6) a 779 mmHg y 62 ºC?



P= 779
V= 1
R= 0.0821
T= 335.15
masa_molar: 352.02

D=(((779/760)*masa_molar)/(R*T))
print("la densidad es:",round(D,2))

# %% [markdown]
# # Pregunta 15.

# %%
# Un químico ha sintetizado un compuesto gaseoso amarillo verdoso de cloro y
# oxígeno, y encuentra que su densidad es de 7.71 g/L a 36 ºC y 2.88 atm.
# Calcule la masa molar del compuesto y determine su fórmula molecular.

D= 7.71
R= 0.0821
T= 309.15
P= 2.88

masa_molar= ((D*R*T)/(P))
print("la masa molar del compuesto es:",masa_molar)

# %% [markdown]
# # Pregunta 16.

# %%
# La densidad de un compuesto orgánico gaseoso es de 3.38 g/L a 40 ºC y 1.97 atm.
# ¿Cuál es su masa molar?


D= 3.38
V= 22.4
R= 0.0821
T= 313.15
P= 1.97

masa_molar= ((D*V*R*T)/P)
print("su masa molar es de:",masa_molar)

# %% [markdown]
# # Pregunta 17.

# %%
# El análisis químico de un compuesto gaseoso mostró que contiene 33.0% de
# silicio y 67.0% de flúor en masa. A 35 ºC, 0.210 L del compuesto ejercen una
# presión de 1.70 atm. Si la masa de 0.210 L del gas fue de 2.38 g, calcule la
# fórmula molecular del compuesto.

# %% [markdown]
# # Pregunta 18.

# %%
# Un compuesto gaseoso está formado por 78.14% de boro y 21.86% de hidrógeno.
# A 27 ºC, 74.3 mL del gas ejercen una presión de 1.12 atm. Si la masa del gas
# fue de 0.0934 g, ¿cuál es su fórmula molecular?

# %% [markdown]
# # Pregunta 19.

# %%
# La combustión de acetileno con oxígeno puro produce una flama de muy alta
# temperatura utilizada para la soldadura y el corte de metales. Calcule el
# volumen de O2 (en litros) requerido para la combustión completa de 7.64 L de
# acetileno (C2H2) a la misma temperatura y presión:
# C2H2 + O2 --> CO2 + H2O

# %% [markdown]
# # Pregunta 20.

# %%
# La azida de sodio (NaN3) se usa en bolsas de aire en algunos automóviles.
# El impacto de una colisión desencadena la descomposición de la NaN3 de la
# siguiente manera: 2NaN3(s) --> 2Na(s) + 3N2(g)
# El nitrógeno gaseoso producido infla rápidamente la bolsa que se encuentra
# entre el conductor y el parabrisas. Calcule el volumen de N2 generado a 80 ºC
# y 823 mmHg por la descomposición de 60.0 g de NaN3.
